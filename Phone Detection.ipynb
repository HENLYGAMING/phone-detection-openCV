# %%
import cv2
import warnings
warnings.filterwarnings('ignore')

# %%
from ultralytics import YOLO

model = YOLO('yolov8s.pt')
# model.to('cuda')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt'...
# 100%|█████████████████████████████████████████████████████████████████████████████| 21.5M/21.5M [00:07<00:00, 2.87MB/s]

# %%
cell_phone_id = 67

video = cv2.VideoCapture(0)

while True:
  check, frame = video.read()

  if not check:
    break

  results = model(frame)[0]

  for box in results.boxes:
    cls_id = int(box.cls[0])

    if cls_id == cell_phone_id:
      x1, y1, x2, y2 = map(int, box.xyxy[0])
      cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
      cv2.putText(frame, 'Phone', (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)


  cv2.imshow('Video', frame)

  if cv2.waitKey(1) == ord('q'):
    break

video.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 285.7ms
# Speed: 4.9ms preprocess, 285.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 233.4ms
# Speed: 5.4ms preprocess, 233.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 232.5ms
# Speed: 2.5ms preprocess, 232.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.9ms
# Speed: 2.3ms preprocess, 205.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 201.2ms
# Speed: 2.6ms preprocess, 201.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 195.4ms
# Speed: 3.2ms preprocess, 195.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.9ms
# Speed: 2.4ms preprocess, 207.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 199.8ms
# Speed: 3.0ms preprocess, 199.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 198.4ms
# Speed: 2.7ms preprocess, 198.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 207.0ms
# Speed: 2.3ms preprocess, 207.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 182.2ms
# Speed: 2.7ms preprocess, 182.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 194.3ms
# Speed: 2.6ms preprocess, 194.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.2ms
# Speed: 2.8ms preprocess, 204.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.1ms
# Speed: 2.4ms preprocess, 205.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 226.3ms
# Speed: 2.6ms preprocess, 226.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 369.7ms
# Speed: 2.4ms preprocess, 369.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 247.2ms
# Speed: 3.1ms preprocess, 247.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 271.9ms
# Speed: 2.9ms preprocess, 271.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 233.5ms
# Speed: 2.5ms preprocess, 233.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.3ms
# Speed: 2.3ms preprocess, 212.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 194.7ms
# Speed: 2.3ms preprocess, 194.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 194.1ms
# Speed: 3.6ms preprocess, 194.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 190.3ms
# Speed: 2.4ms preprocess, 190.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 190.8ms
# Speed: 2.5ms preprocess, 190.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 189.8ms
# Speed: 2.4ms preprocess, 189.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 193.7ms
# Speed: 2.4ms preprocess, 193.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 193.5ms
# Speed: 3.3ms preprocess, 193.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 183.8ms
# Speed: 2.5ms preprocess, 183.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 190.3ms
# Speed: 2.9ms preprocess, 190.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 206.6ms
# Speed: 2.6ms preprocess, 206.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 187.0ms
# Speed: 2.2ms preprocess, 187.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 180.6ms
# Speed: 2.4ms preprocess, 180.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 189.9ms
# Speed: 2.4ms preprocess, 189.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.5ms
# Speed: 2.6ms preprocess, 186.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 182.5ms
# Speed: 2.5ms preprocess, 182.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 198.3ms
# Speed: 2.7ms preprocess, 198.3ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 209.2ms
# Speed: 2.5ms preprocess, 209.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 199.8ms
# Speed: 2.5ms preprocess, 199.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 187.6ms
# Speed: 2.7ms preprocess, 187.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 184.9ms
# Speed: 2.5ms preprocess, 184.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 190.5ms
# Speed: 2.3ms preprocess, 190.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 204.6ms
# Speed: 2.6ms preprocess, 204.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.2ms
# Speed: 2.4ms preprocess, 186.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 191.7ms
# Speed: 2.8ms preprocess, 191.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.5ms
# Speed: 2.8ms preprocess, 186.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 frisbee, 185.4ms
# Speed: 2.5ms preprocess, 185.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 191.7ms
# Speed: 2.3ms preprocess, 191.7ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 skateboard, 186.1ms
# Speed: 2.6ms preprocess, 186.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 190.2ms
# Speed: 2.1ms preprocess, 190.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 188.8ms
# Speed: 2.3ms preprocess, 188.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 sports ball, 189.7ms
# Speed: 2.5ms preprocess, 189.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 193.0ms
# Speed: 2.6ms preprocess, 193.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 184.7ms
# Speed: 2.3ms preprocess, 184.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.0ms
# Speed: 2.6ms preprocess, 186.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 191.3ms
# Speed: 2.4ms preprocess, 191.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 203.6ms
# Speed: 2.8ms preprocess, 203.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 195.4ms
# Speed: 2.6ms preprocess, 195.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 189.1ms
# Speed: 3.1ms preprocess, 189.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cell phones, 1 clock, 189.4ms
# Speed: 2.7ms preprocess, 189.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 190.5ms
# Speed: 3.1ms preprocess, 190.5ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 193.2ms
# Speed: 2.3ms preprocess, 193.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 190.8ms
# Speed: 2.7ms preprocess, 190.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 185.6ms
# Speed: 2.7ms preprocess, 185.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 190.6ms
# Speed: 3.7ms preprocess, 190.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cell phones, 293.9ms
# Speed: 2.5ms preprocess, 293.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 cell phones, 192.5ms
# Speed: 2.5ms preprocess, 192.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 laptop, 1 cell phone, 191.2ms
# Speed: 2.2ms preprocess, 191.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 188.5ms
# Speed: 2.6ms preprocess, 188.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 186.0ms
# Speed: 2.6ms preprocess, 186.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 193.6ms
# Speed: 3.0ms preprocess, 193.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 sports ball, 186.9ms
# Speed: 2.7ms preprocess, 186.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.8ms
# Speed: 2.7ms preprocess, 186.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 187.4ms
# Speed: 2.3ms preprocess, 187.4ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.8ms
# Speed: 3.1ms preprocess, 186.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 192.9ms
# Speed: 2.4ms preprocess, 192.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 184.1ms
# Speed: 2.2ms preprocess, 184.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 186.6ms
# Speed: 2.7ms preprocess, 186.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 185.7ms
# Speed: 2.4ms preprocess, 185.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 197.4ms
# Speed: 3.2ms preprocess, 197.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 191.1ms
# Speed: 2.9ms preprocess, 191.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 197.5ms
# Speed: 2.8ms preprocess, 197.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 196.1ms
# Speed: 3.7ms preprocess, 196.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
